# %% [markdown]
# Distance euclidienne

# %% [markdown]
# ![1*_ftwbnr74RtEwnquHPg2rg.png](attachment:1*_ftwbnr74RtEwnquHPg2rg.png)

# %%
import numpy as np
a = np.array((1, 2, 3)) #--> ligne 0
b = np.array((4, 5, 6)) #--> ligne 1

dist = np.sqrt(np.sum(np.square(a-b)))

print(dist)
# Out:
# 5.196152422706632

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Distance Manhattan

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Distance Minkowski

# %% [markdown]
# ![image.png](attachment:image.png)
